# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '/Users/sroca/Postdoc/Analysis/READ_ART_python')
from READ_ART import read_ART

path= '/Users/sroca/Postdoc/UNAM/Aillsim/N106/RUNbar/'
filename= "PMcrs0a0.6490.DAT"
#path= '/Users/sroca/Desktop/Ciencia/RODIN/CIbar/N106/'
#filename= "PMcrs0.DAT"
nstars = 999978 ## From the RODIN ICs generator

mass,x,y,z,vx,vy,vz,Id=read_ART(path,filename,nstars)
# Out:
# /Users/sroca/Postdoc/UNAM/Aillsim/N106/RUNbar/ PMcrs0a0.6490.DAT 999978
# discovered %s:%s particle_data /Users/sroca/Postdoc/UNAM/Aillsim/N106/RUNbar/PMcrs0a0.6490.DAT
# discovered %s:%s particle_header /Users/sroca/Postdoc/UNAM/Aillsim/N106/RUNbar/PMcrda0.6490.DAT
# /Users/sroca/Postdoc/Analysis/READ_ART_python/READ_ART.py:138: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   for specie in range(n):
# /Users/sroca/Postdoc/Analysis/READ_ART_python/READ_ART.py:142: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   ls_nonzero = np.diff(lspecies)[:n-1]
# /Users/sroca/Postdoc/Analysis/READ_ART_python/READ_ART.py:155: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   self.parameters['wspecies'] = wspecies[:n]
# ...

# %%
plt.plot(x[0],y[0],'k.')
plt.show()

# %%
center=ad.quantities.center_of_mass(use_particles=True)
c=center
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'Stars_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'DarkMatter_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ParticlePlot(ds, 'particle_position_x', 'particle_position_y', 'particle_mass', width=(0.01, 0.01))
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'Stars_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'DarkMatter_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ParticlePlot(ds, 'particle_position_z', 'particle_position_x', 'particle_mass', width=(0.01, 0.01))
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'Stars_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'DarkMatter_density')],width=(10, 'pc'),center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ParticlePlot(ds, 'particle_position_y', 'particle_position_z', 'particle_mass', width=(0.01, 0.01))
p.show()
# Out:
# yt : [INFO     ] 2020-10-14 11:03:44,196 Projection completed
# yt : [INFO     ] 2020-10-14 11:03:44,197 xlim = -0.004996 0.005004
# yt : [INFO     ] 2020-10-14 11:03:44,198 ylim = -0.005000 0.005000
# yt : [INFO     ] 2020-10-14 11:03:44,200 xlim = -0.004996 0.005004
# yt : [INFO     ] 2020-10-14 11:03:44,202 ylim = -0.005000 0.005000
# yt : [INFO     ] 2020-10-14 11:03:44,206 Making a fixed resolution buffer of (('deposit', 'Stars_density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# ---------------------------------------------------------------------------
# YTFieldNotFound                           Traceback (most recent call last)
# <ipython-input-8-6b7f78bd01ff> in <module>()
#       6 p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
#       7 p.show()
# ----> 8 p = yt.ProjectionPlot(ds, 'z', [('deposit', 'DarkMatter_density')],width=(10, 'pc'),center=c)
# ...

# %%
#center=[0.0006,0.0016,0.0004]
#v, c = ds.find_max(('deposit', 'Stars_density'))
width=(2.5, 'pc')
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
# Out:
# yt : [INFO     ] 2017-07-18 10:48:44,484 Projection completed
# yt : [INFO     ] 2017-07-18 10:48:44,485 xlim = 0.001253 0.003753
# yt : [INFO     ] 2017-07-18 10:48:44,485 ylim = -0.001207 0.001293
# yt : [INFO     ] 2017-07-18 10:48:44,488 xlim = 0.001253 0.003753
# yt : [INFO     ] 2017-07-18 10:48:44,489 ylim = -0.001207 0.001293
# yt : [INFO     ] 2017-07-18 10:48:44,491 Making a fixed resolution buffer of (('deposit', 'Stars_density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2017-07-18 10:48:58,848 Projection completed
# yt : [INFO     ] 2017-07-18 10:48:58,849 xlim = 0.001253 0.003753
# yt : [INFO     ] 2017-07-18 10:48:58,850 ylim = -0.001207 0.001293
# yt : [INFO     ] 2017-07-18 10:48:58,853 xlim = 0.001253 0.003753
# yt : [INFO     ] 2017-07-18 10:48:58,854 ylim = -0.001207 0.001293
# ...

# %%
c2=ad.quantities.max_location(("deposit", "DarkMatter_density"))
c=[c2[2],c2[3],c2[4]]
width=(5, 'pc')
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'z', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'x', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'Stars_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'Stars_density'), True)
p.set_zlim([('deposit', 'Stars_density')], 1e-10, 5e-8)
p.show()
p = yt.ProjectionPlot(ds, 'y', [('deposit', 'DarkMatter_density')],width=width,center=c)
#p.set_zlim([('deposit', 'Stars_mass')], 1e39, 1e41)
p.set_log(('deposit', 'DarkMatter_density'), True)
p.set_zlim([('deposit', 'DarkMatter_density')], 1e-10, 5e-8)
# Out:
# yt : [INFO     ] 2017-07-18 10:47:51,746 Projection completed
# yt : [INFO     ] 2017-07-18 10:47:51,747 xlim = 0.000003 0.005003
# yt : [INFO     ] 2017-07-18 10:47:51,750 ylim = -0.002457 0.002543
# yt : [INFO     ] 2017-07-18 10:47:51,759 xlim = 0.000003 0.005003
# yt : [INFO     ] 2017-07-18 10:47:51,760 ylim = -0.002457 0.002543
# yt : [INFO     ] 2017-07-18 10:47:51,762 Making a fixed resolution buffer of (('deposit', 'Stars_density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2017-07-18 10:48:06,254 Projection completed
# yt : [INFO     ] 2017-07-18 10:48:06,255 xlim = 0.000003 0.005003
# yt : [INFO     ] 2017-07-18 10:48:06,256 ylim = -0.002457 0.002543
# yt : [INFO     ] 2017-07-18 10:48:06,260 xlim = 0.000003 0.005003
# yt : [INFO     ] 2017-07-18 10:48:06,261 ylim = -0.002457 0.002543
# ...

# %%
N1=5.737*10**11
N2=3.728*10**11
N3=4.6*10**10
N4=9.34*10**9
N5=2.306*10**8
N6=4.682*10**7
N7=1.156*10**6-1.66*10**5
N8=0#1.404*10**5

MV1=16.5
MV2=12.3
MV3=7.4
MV4=5.1
MV5=1.6
MV6=-0.1
MV7=-3.2
MV8=-7.5

BV1=1.97
BV2=1.6
BV3=1.15
BV4=0.68
BV5=0.44
BV6=0.15
BV7=-0.17
BV8=-0.33

Num=N1*10**(-0.4*(BV1+MV1))+N2*10**(-0.4*(BV2+MV2))+N3*10**(-0.4*(BV3+MV3))+N4*10**(-0.4*(BV4+MV4))+N5*10**(-0.4*(BV5+MV5))+N6*10**(-0.4*(BV6+MV6))+N7*10**(-0.4*(BV7+MV7))+N8*10**(-0.4*(BV8+MV8))

Deno=N1*10**(-0.4*(MV1))+N2*10**(-0.4*(MV2))+N3*10**(-0.4*(MV3))+N4*10**(-0.4*(MV4))+N5*10**(-0.4*(MV5))+N6*10**(-0.4*(MV6))+N7*10**(-0.4*(MV7))+N8*10**(-0.4*(MV8))

print(Num, Deno,-2.5*np.log10(Num/Deno))
# Out:
# (166074063.10932487, 263274536.4793428, 0.5002676143300246)

# %%
10**(-0.5/2.5)
# Out:
# 0.6309573444801932
